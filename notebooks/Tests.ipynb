# %%
import os
import subprocess

# This snippet assumes you run setup first

# Replace 'test.csv' with THE NAME of the file you're going to store in the bucket (don't delete the quotation marks)
destination_filename = '1kg_acp_final.bcf.csi'

########################################################################
##
################# DON'T CHANGE FROM HERE ###############################
##
########################################################################

# get the bucket name
my_bucket = os.getenv('WORKSPACE_BUCKET')

# copy csv file to the bucket
args = ["gsutil", "cp", f"./{destination_filename}", f"{my_bucket}/Data/"]
output = subprocess.run(args, capture_output=True)

# print output from gsutil
output.stderr
# Out:
# b'Copying file://./1kg_acp_final.bcf.csi [Content-Type=application/octet-stream]...\n/ [0 files][    0.0 B/842.0 KiB]                                                \r/ [1 files][842.0 KiB/842.0 KiB]                                                \r\nOperation completed over 1 objects/842.0 KiB.                                    \n'

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.bim .
# Out:
# Copying gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.bim...
# / [0 files][    0.0 B/ 69.1 MiB]

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v6/wgs/vcf/aux/ancestry/ancestry_preds.tsv .
# Out:
# Copying gs://fc-aou-datasets-controlled/v6/wgs/vcf/aux/ancestry/ancestry_preds.tsv...
# - [1 files][ 38.8 MiB/ 38.8 MiB]
# Operation completed over 1 objects/38.8 MiB.

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pgen .
# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.psam .
# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pvar .
# Out:
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pgen...
# / [1 files][ 16.3 GiB/ 16.3 GiB]   57.4 MiB/s
# Operation completed over 1 objects/16.3 GiB.
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.psam...
# / [1 files][  4.4 MiB/  4.4 MiB]
# Operation completed over 1 objects/4.4 MiB.
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pvar...
# | [1 files][153.0 MiB/153.0 MiB]
# Operation completed over 1 objects/153.0 MiB.

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen
# Out:
#  86.57 GiB  2025-01-20T21:41:57Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.pgen
#   4.35 MiB  2025-01-20T21:55:40Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.psam
# 770.31 MiB  2025-01-20T21:41:54Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.pvar
#  55.48 GiB  2025-01-20T21:41:54Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr10.pgen
#   4.35 MiB  2025-01-20T21:55:38Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr10.psam
# 490.15 MiB  2025-01-20T21:41:54Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr10.pvar
#  52.07 GiB  2025-01-20T21:41:56Z  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr11.pgen
# ...

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux
# Out:
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/ancestry/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/pgx/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/phasing/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/qc/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/relatedness/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/vat/

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.*

# %%
# %%bash
#
# if [ ! -d rye ]
# then
#     git clone -b dev https://github.com/healthdisparities/rye/
# fi
# Out:
# Cloning into 'rye'...

# %%
# %%bash
#
# #Install the dependencies for this.
# R -e 'install.packages(c("nnls", "optparse", "Hmisc"), repos = "https://cloud.r-project.org")'
# Out:
# R version 4.4.0 (2024-04-24) -- "Puppy Cup"
# Copyright (C) 2024 The R Foundation for Statistical Computing
# Platform: x86_64-pc-linux-gnu
#
# R is free software and comes with ABSOLUTELY NO WARRANTY.
# You are welcome to redistribute it under certain conditions.
# Type 'license()' or 'licence()' for distribution details.
#
#   Natural language support but running in an English locale
#
# R is a collaborative project with many contributors.
# Type 'contributors()' for more information and
# 'citation()' on how to cite R or R packages in publications.
#
# Type 'demo()' for some demos, 'help()' for on-line help, or
# 'help.start()' for an HTML browser interface to help.
# Type 'q()' to quit R.
#
# > install.packages(c("nnls", "optparse", "Hmisc"), repos = "https://cloud.r-project.org")
# Installing packages into ‘/home/jupyter/packages’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘checkmate’, ‘getopt’, ‘htmlTable’, ‘viridis’, ‘Formula’
#
# ...

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v8/microarray/plink/
# Out:
# 181.13 GiB  2025-01-22T15:18:27Z  gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.bed
#  69.06 MiB  2025-01-22T15:18:25Z  gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.bim
#    8.1 MiB  2025-01-22T15:18:28Z  gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.fam
# TOTAL: 3 objects, 194565977045 bytes (181.2 GiB)

# %%
# !!gsutil -m -u $GOOGLE_PROJECT ls gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates
# Out:
# ['gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.Q',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.fam',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.Q',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.fam']
