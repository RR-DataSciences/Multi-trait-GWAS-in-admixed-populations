# %%
import os
import subprocess

# This snippet assumes you run setup first

# Replace 'test.csv' with THE NAME of the file you're going to store in the bucket (don't delete the quotation marks)
destination_filename = '1kg_acp_final.bcf.csi'

########################################################################
##
################# DON'T CHANGE FROM HERE ###############################
##
########################################################################

# get the bucket name
my_bucket = os.getenv('WORKSPACE_BUCKET')

# copy csv file to the bucket
args = ["gsutil", "cp", f"./{destination_filename}", f"{my_bucket}/Data/"]
output = subprocess.run(args, capture_output=True)

# print output from gsutil
output.stderr
# Out:
# b'Copying file://./1kg_acp_final.bcf.csi [Content-Type=application/octet-stream]...\n/ [0 files][    0.0 B/842.0 KiB]                                                \r/ [1 files][842.0 KiB/842.0 KiB]                                                \r\nOperation completed over 1 objects/842.0 KiB.                                    \n'

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://vwb-aou-datasets-controlled/v8/microarray/plink/arrays.bim .
# Out:
# Copying gs://fc-aou-datasets-controlled/v8/microarray/plink/arrays.bim...
# / [0 files][    0.0 B/ 69.1 MiB]

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://vwb-aou-datasets-controlled/v6/wgs/vcf/aux/ancestry/ancestry_preds.tsv .
# Out:
# Copying gs://fc-aou-datasets-controlled/v6/wgs/vcf/aux/ancestry/ancestry_preds.tsv...
# - [1 files][ 38.8 MiB/ 38.8 MiB]
# Operation completed over 1 objects/38.8 MiB.

# %%
# !gsutil -u $GOOGLE_PROJECT cp gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pgen .
# !gsutil -u $GOOGLE_PROJECT cp gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.psam .
# !gsutil -u $GOOGLE_PROJECT cp gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pvar .
# Out:
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pgen...
# / [1 files][ 16.3 GiB/ 16.3 GiB]   57.4 MiB/s
# Operation completed over 1 objects/16.3 GiB.
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.psam...
# / [1 files][  4.4 MiB/  4.4 MiB]
# Operation completed over 1 objects/4.4 MiB.
# Copying gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr21.pvar...
# | [1 files][153.0 MiB/153.0 MiB]
# Operation completed over 1 objects/153.0 MiB.

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
#  86.57 GiB  2025-10-04T18:48:58Z  gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.pgen
#   4.35 MiB  2025-10-04T18:49:02Z  gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.psam
# 770.31 MiB  2025-10-04T18:49:20Z  gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr1.pvar
#  55.48 GiB  2025-10-04T19:11:59Z  gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr10.pgen
#   4.35 MiB  2025-10-04T19:12:04Z  gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/acaf_threshold/pgen/acaf_threshold.chr10.psam
# ...

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh vwb://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux
# Out:
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/ancestry/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/pgx/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/phasing/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/qc/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/relatedness/
#                                  gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/vat/

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://vwb-aou-datasets-controlled/v8/microarray/plink/arrays.*

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://vwb-aou-datasets-controlled/v8/microarray/plink/
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# 181.13 GiB  2025-10-16T18:38:42Z  gs://vwb-aou-datasets-controlled/v8/microarray/plink/arrays.bed
#  69.06 MiB  2025-10-16T17:34:56Z  gs://vwb-aou-datasets-controlled/v8/microarray/plink/arrays.bim
#    8.1 MiB  2025-10-16T17:35:33Z  gs://vwb-aou-datasets-controlled/v8/microarray/plink/arrays.fam
# TOTAL: 3 objects, 194565977045 bytes (181.2 GiB)

# %%
# !!gsutil -m -u $GOOGLE_PROJECT ls gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates
# Out:
# ['gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.Q',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.fam',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.Q',
#  'gs://fc-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.fam']

# %%
# !gsutil -m -u $$GOOGLE_PROJECT ls gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.Q
# gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/aou_admixture_estimates_rye_v8.fam
# gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.Q
# gs://vwb-aou-datasets-controlled/v8/wgs/short_read/snpindel/aux/admixture_estimates/reference_admixture_estimates_rye_v8.fam

# %%
# !gsutil -m -u $$GOOGLE_PROJECT ls gs://workspace-bucket-wb-perky-cabbage-8342/Data
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# gs://workspace-bucket-wb-perky-cabbage-8342/Data/df_bc_10k_nb_BC_WITHIN_5Y.tsv
# gs://workspace-bucket-wb-perky-cabbage-8342/Data/df_bc_ko_at_inclusion_361k_nb_BC_WITHIN_5Y.tsv
# gs://workspace-bucket-wb-perky-cabbage-8342/Data/list_id_bc_in_5y_bc_ko_at_inclusion_nb_BC_WITHIN_5Y.txt
# gs://workspace-bucket-wb-perky-cabbage-8342/Data/list_id_bc_in_all_time_bc_ko_at_inclusion_nb_BC_WITHIN_5Y.txt

# %%
# !echo $WORKSPACE_CDR
# Out:
# wb-silky-artichoke-2408.C2024Q3R9
