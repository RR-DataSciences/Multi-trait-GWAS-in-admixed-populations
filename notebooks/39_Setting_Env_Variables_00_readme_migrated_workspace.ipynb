# %% [markdown]
# # How to work with env variables in a newly migrated workspace (from RW1.0 to RW2.0)
#
# As of 06/29/2026, we need to either manually or use scripts to setup these env variables.
#
# In this notebook, we will demo how to make two important variables including `$workspace_bucket` and `$WORKSPACE_CDR` work in a newly migrated workspace
#
# In this newly migrated workspace, we can check the default env variables first

# %%
# !wb resource list

# %%
# !gcloud storage ls gs://ou-tutorial-notebooks-wb-sunny-radish-6214

# %%
# !gcloud storage cp gs://aou-tutorial-notebooks-wb-sunny-radish-6214/Setting_Env_Variables* .

# %%
# %run Setting_Env_Variables.py

# %%
# !echo $WORKSPACE_CDR

# %%
# !echo $WORKSPACE_BUCKET

# %%
# %run Setting_Env_Variables_p2.py
